# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set (color_codes = True)
import warnings 
warnings.filterwarnings('ignore')

# %%
import os

# %%
os.chdir('C:\\Users\\nidhi\\Downloads')

# %%
df=pd.read_csv('7. smartphones.csv')

# %%
df.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 0                        0  ...               64          6.1            60
# ...

# %% [markdown]
# # descriptive analysis

# %%
df.describe().T
# Out:
#                            count          mean           std      min  \
# price                      980.0  32520.504082  39531.812669  3499.00
# avg_rating                 879.0      7.825825      0.740285     6.00
# 5G_or_not                  980.0      0.560204      0.496616     0.00
# num_cores                  974.0      7.772074      0.836845     4.00
# processor_speed            938.0      2.427217      0.464090     1.20
# battery_capacity           969.0   4817.748194   1009.540054  1821.00
# fast_charging_available    980.0      0.854082      0.353205     0.00
# fast_charging              769.0     46.126138     34.277870    10.00
# ram_capacity               980.0      6.560204      2.744378     1.00
# internal_memory            980.0    141.036735    107.134516     8.00
# screen_size                980.0      6.536765      0.349162     3.54
# refresh_rate               980.0     92.256122     28.988052    60.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 879 non-null    float64
#  4   5G_or_not                  980 non-null    int64
#  5   processor_brand            960 non-null    object
#  6   num_cores                  974 non-null    float64
#  7   processor_speed            938 non-null    float64
#  8   battery_capacity           969 non-null    float64
#  9   fast_charging_available    980 non-null    int64
#  10  fast_charging              769 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    int64
# ...

# %% [markdown]
# #check the type of datatype

# %%
df['fast_charging_available'].value_counts()
# Out:
# fast_charging_available
# 1    837
# 0    143
# Name: count, dtype: int64

# %%
df['5G_or_not'].value_counts()
# Out:
# 5G_or_not
# 1    549
# 0    431
# Name: count, dtype: int64

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8.0    899
# 6.0     39
# 4.0     36
# Name: count, dtype: int64

# %%
df['extended_memory_available'].value_counts()
# Out:
# extended_memory_available
# 1    618
# 0    362
# Name: count, dtype: int64

# %%
df['num_rear_cameras'].value_counts()
# Out:
# num_rear_cameras
# 3    551
# 2    208
# 4    156
# 1     65
# Name: count, dtype: int64

# %%
df['internal_memory'].value_counts()
# Out:
# internal_memory
# 128     523
# 64      193
# 256     157
# 32       67
# 512      22
# 16       12
# 1024      5
# 8         1
# Name: count, dtype: int64

# %%
df[['num_rear_cameras', 'num_cores', 'extended_memory_available', 'fast_charging_available', '5G_or_not',
    'internal_memory']] = df[['num_rear_cameras', 'num_cores', 'extended_memory_available', 'fast_charging_available', '5G_or_not',
      'internal_memory']].astype('object')

# %%
df.head(1)
# Out:
#   brand_name            model  price  avg_rating 5G_or_not processor_brand  \
# 0      apple  Apple iPhone 11  38999         7.3         0          bionic
#
#   num_cores  processor_speed  battery_capacity fast_charging_available  ...  \
# 0       6.0             2.65            3110.0                       0  ...
#
#    internal_memory  screen_size refresh_rate  num_rear_cameras   os  \
# 0               64          6.1           60                 2  ios
#
#   primary_camera_rear primary_camera_front  extended_memory_available  \
# 0                12.0                 12.0                          0
#
#    resolution_height resolution_width
# 0               1792              828
#
# [1 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 879 non-null    float64
#  4   5G_or_not                  980 non-null    object
#  5   processor_brand            960 non-null    object
#  6   num_cores                  974 non-null    object
#  7   processor_speed            938 non-null    float64
#  8   battery_capacity           969 non-null    float64
#  9   fast_charging_available    980 non-null    object
#  10  fast_charging              769 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    object
# ...

# %% [markdown]
# # split the dataset on based of numerical and categorical datatype

# %%
df_num=df.select_dtypes(np.number)

# %%
df_num.head(1)
# Out:
#    price  avg_rating  processor_speed  battery_capacity  fast_charging  \
# 0  38999         7.3             2.65            3110.0            NaN
#
#    ram_capacity  screen_size  refresh_rate  primary_camera_rear  \
# 0             4          6.1            60                 12.0
#
#    primary_camera_front  resolution_height  resolution_width
# 0                  12.0               1792               828

# %%
df_num.columns
# Out:
# Index(['price', 'avg_rating', 'processor_speed', 'battery_capacity',
#        'fast_charging', 'ram_capacity', 'screen_size', 'refresh_rate',
#        'primary_camera_rear', 'primary_camera_front', 'resolution_height',
#        'resolution_width'],
#       dtype='object')

# %%
#Numerical data in the dataset are 'price', 'avg_rating', 'processor_speed', 'battery_capacity','fast_charging', 'ram_capacity', 'screen_size', 'refresh_rate',
#'primary_camera_rear', 'primary_camera_front', 'resolution_height',
#resolution_width'

# %%
df_cat=df.select_dtypes('object')

# %%
df_cat.columns
# Out:
# Index(['brand_name', 'model', '5G_or_not', 'processor_brand', 'num_cores',
#        'fast_charging_available', 'internal_memory', 'num_rear_cameras', 'os',
#        'extended_memory_available'],
#       dtype='object')

# %%
#Categorical data in the dataset 'brand_name', 'model', '5G_or_not', 'processor_brand', 'num_cores','fast_charging_available', 'internal_memory', 'num_rear_cameras', 'os',
#'extended_memory_available'

# %% [markdown]
# # Distribution of dataset

# %%
plt.figure(figsize=(20, 15))
sns.pairplot(df_num, kind='scatter', diag_kind='kde', plot_kws={'color':'skyblue'})
plt.show()

# %% [markdown]
# # check the distribution of categorical datatype

# %%
#univariate analysis of categiorical data

# %%
#check the countplot of various categorical data 
df_cat['5G_or_not'].value_counts().plot(kind='bar',color ='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('5G or not')
plt.ylabel('Frequency')
plt.title('Histogram of 5g available or not')
plt.show()

# %%
df_cat['5G_or_not'].value_counts()
#distribution of 5g_or_not of data
# Out:
# 5G_or_not
# 1    549
# 0    431
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
df_cat['brand_name'].value_counts().plot(kind='bar', color ='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('Brand Name')
plt.ylabel('Frequency')
plt.title('Histogram of Brand Names')
plt.show()
plt.show()

# %%
df_cat['extended_memory_available'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('extended_memory_available')
plt.ylabel('Frequency')
plt.title('Histogram of extended_memory_available')
plt.show()

# %%
df_cat['fast_charging_available'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('fast_charging_available')
plt.ylabel('Frequency')
plt.title('Histogram of fast_charging_available')
plt.show()

# %%
df_cat.columns
# Out:
# Index(['brand_name', 'model', '5G_or_not', 'processor_brand', 'num_cores',
#        'fast_charging_available', 'internal_memory', 'num_rear_cameras', 'os',
#        'extended_memory_available'],
#       dtype='object')

# %%
df_cat['num_cores'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('num_cores')
plt.ylabel('Frequency')
plt.title('Histogram of num_cores')
plt.show()

# %%
df_cat['num_rear_cameras'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('num_rear_cameras')
plt.ylabel('Frequency')
plt.title('Histogram of num_rear_cameras')
plt.show()

# %%
df_cat['os'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('os')
plt.ylabel('Frequency')
plt.title('Histogram of os')
plt.show()

# %%
df_cat['processor_brand'].value_counts().plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)  
plt.xlabel('processor_brand')
plt.ylabel('Frequency')
plt.title('Histogram of processor_brand')
plt.show()

# %% [markdown]
# # Checking the outliers

# %%
plt.figure(figsize=(10,8))
df_num.boxplot(color='skyblue')
plt.title('distribution of all the numeric variable',fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,8))
df_num.loc[:,['battery_capacity','fast_charging','ram_capacity','screen_size','primary_camera_rear','primary_camera_front',
              'resolution_height','resolution_width']].boxplot(color='skyblue')
plt.title('distribution of all the numeric variable',fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
fig, ax = plt.subplots(nrows=6,ncols=2,figsize=(20,15))
for variable, subplot in zip(df_num.columns, ax.flatten()):
    sns.distplot(df_num[variable],color='skyblue', ax = subplot)
plt.show()

# %%
df_num.skew()
# Out:
# price                   6.591791
# avg_rating             -0.698999
# processor_speed         0.188336
# battery_capacity        9.260986
# fast_charging           1.645571
# ram_capacity            0.745896
# screen_size            -2.116199
# refresh_rate            0.297733
# primary_camera_rear     1.770579
# primary_camera_front    1.439294
# resolution_height      -0.694040
# resolution_width        1.818385
# dtype: float64

# %%
#price,screen-size,primart-front camera,battery capacity are highly skewed

# %%
df_num.kurtosis()
# Out:
# price                    79.191922
# avg_rating               -0.300681
# processor_speed          -0.666667
# battery_capacity        154.678982
# fast_charging             3.410268
# ram_capacity              0.995368
# screen_size              17.475291
# refresh_rate             -0.665531
# primary_camera_rear       6.064669
# primary_camera_front      2.237333
# resolution_height         1.000787
# resolution_width          6.422227
# dtype: float64

# %% [markdown]
# # outliers treatment

# %%
q1 = df_num.quantile(0.25)
q3 = df_num.quantile(0.75)
IQR = q3 - q1
IQR
# Out:
# price                   22492.50
# avg_rating                  1.00
# processor_speed             0.79
# battery_capacity          500.00
# fast_charging              48.00
# ram_capacity                4.00
# screen_size                 0.17
# refresh_rate               60.00
# primary_camera_rear        40.00
# primary_camera_front        8.00
# resolution_height         796.00
# resolution_width            0.00
# dtype: float64

# %%
df_num.shape
# Out:
# (980, 12)

# %%
df.shape
# Out:
# (980, 22)

# %%
df_num=df_num[~((df_num < ( q1 - 1.5 * IQR)) | (df_num > ( q3 + 1.5 * IQR))).any(axis = 1)]
df_num.head(1)
# Out:
#     price  avg_rating  processor_speed  battery_capacity  fast_charging  \
# 54  14990         8.5              2.4            5000.0            NaN
#
#     ram_capacity  screen_size  refresh_rate  primary_camera_rear  \
# 54             8          6.8            60                 48.0
#
#     primary_camera_front  resolution_height  resolution_width
# 54                  16.0               2460              1080

# %%
df_num.shape
# Out:
# (353, 12)

# %%
plt.figure(figsize=(10,8))
df_num.boxplot(color='skyblue')
plt.title('distribution of all the numeric variable',fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,8))
df_num.loc[:,['battery_capacity','ram_capacity','primary_camera_rear','primary_camera_front',
              'resolution_height','resolution_width']].boxplot(color='skyblue')
plt.title('distribution of all the numeric variable',fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(20,15))
df_num.loc[:,['battery_capacity','ram_capacity','primary_camera_rear','primary_camera_front',
              'resolution_height']].boxplot(color='skyblue')
plt.title('distribution of all the numeric variable',fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %%
fig, ax = plt.subplots(nrows=6,ncols=2,figsize=(20,15))
for variable, subplot in zip(df_num.columns, ax.flatten()):
    sns.distplot(df_num[variable],color='skyblue', ax = subplot)
plt.show()

# %%
df_num.skew()
# Out:
# price                   1.838508
# avg_rating             -0.248798
# processor_speed         0.995496
# battery_capacity       -1.676208
# fast_charging           1.402103
# ram_capacity            0.515333
# screen_size            -0.023843
# refresh_rate           -0.193814
# primary_camera_rear     1.455994
# primary_camera_front   -1.078531
# resolution_height      -2.261536
# resolution_width        0.000000
# dtype: float64

# %% [markdown]
# # Missing value

# %%
df.isnull().any()
#there is presence of miising value in avg_rating ,processor_brand,num_cores,processor_speed,battery_capacity,fast_charging,os,primary_camera_front
# Out:
# brand_name                   False
# model                        False
# price                        False
# avg_rating                    True
# 5G_or_not                    False
# processor_brand               True
# num_cores                     True
# processor_speed               True
# battery_capacity              True
# fast_charging_available      False
# fast_charging                 True
# ram_capacity                 False
# internal_memory              False
# screen_size                  False
# refresh_rate                 False
# num_rear_cameras             False
# os                            True
# primary_camera_rear          False
# primary_camera_front          True
# extended_memory_available    False
# resolution_height            False
# resolution_width             False
# dtype: bool

# %%
#plot heatmap of missing values 
plt.figure(figsize=(15,8))
sns.heatmap(df.isnull(),cbar = False)
plt.show()

# %%
#check the percentage of missing values 
total=df.isnull().sum().sort_values(ascending=False)
percent=(df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1, keys=['Total','Percentage of missing data'])
missing_data['Type']=df[missing_data.index].dtypes
missing_data
# Out:
#                            Total  Percentage of missing data     Type
# fast_charging                211                   21.530612  float64
# avg_rating                   101                   10.306122  float64
# processor_speed               42                    4.285714  float64
# processor_brand               20                    2.040816   object
# os                            14                    1.428571   object
# battery_capacity              11                    1.122449  float64
# num_cores                      6                    0.612245   object
# primary_camera_front           5                    0.510204  float64
# brand_name                     0                    0.000000   object
# refresh_rate                   0                    0.000000    int64
# resolution_height              0                    0.000000    int64
# extended_memory_available      0                    0.000000   object
# ...

# %%
plt.figure(figsize=[15,8])
df.isnull().sum().plot(kind='bar',color='skyblue')
plt.show()

# %%
#hence the bar chart and percentage distribution depict maxium number of missing data is in fast_charging, avg_raring
#there are 3 categorical data and 5 numerical values

# %% [markdown]
# # Treating missing values

# %%
#Treating first categorical data

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    413
# helio         201
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
print('mode', df['processor_brand'].mode())
print('missing_value' , df['processor_brand'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['processor_brand'],color='skyblue')
# Out:
# mode 0    snapdragon
# Name: processor_brand, dtype: object
# missing_value 20
# <Axes: xlabel='processor_brand', ylabel='Count'>

# %%
df['processor_brand'].fillna(df['processor_brand'].mode()[0], inplace=True)

# %%
print('mode', df['processor_brand'].mode())
print('missing_value' , df['processor_brand'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['processor_brand'],color='skyblue')
# Out:
# mode 0    snapdragon
# Name: processor_brand, dtype: object
# missing_value 0
# <Axes: xlabel='processor_brand', ylabel='Count'>

# %%
df['os'].value_counts()
# Out:
# os
# android    909
# ios         46
# other       11
# Name: count, dtype: int64

# %%
print('mode', df['os'].mode())
print('missing_value' , df['os'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['os'],color='skyblue')
# Out:
# mode 0    android
# Name: os, dtype: object
# missing_value 14
# <Axes: xlabel='os', ylabel='Count'>

# %%
df['os'].fillna(df['os'].mode()[0], inplace=True)

# %%
print('mode', df['os'].mode())
print('missing_value' , df['os'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['os'],color='skyblue')
# Out:
# mode 0    android
# Name: os, dtype: object
# missing_value 0
# <Axes: xlabel='os', ylabel='Count'>

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8.0    899
# 6.0     39
# 4.0     36
# Name: count, dtype: int64

# %%
print('mode', df['num_cores'].mode())
print('missing_value' , df['num_cores'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['num_cores'],color='skyblue')
# Out:
# mode 0    8.0
# Name: num_cores, dtype: object
# missing_value 6
# <Axes: xlabel='num_cores', ylabel='Count'>

# %%
df['num_cores'].fillna(df['num_cores'].mode()[0], inplace=True)

# %%
print('mode', df['num_cores'].mode())
print('missing_value' , df['num_cores'].isnull().sum())
plt.figure(figsize=(15,8))
sns.histplot(df['num_cores'],color='skyblue')
# Out:
# mode 0    8.0
# Name: num_cores, dtype: float64
# missing_value 0
# <Axes: xlabel='num_cores', ylabel='Count'>

# %%
#treating numerical data

# %%
missing_data[percent > 0]
# Out:
#                       Total  Percentage of missing data     Type
# fast_charging           211                   21.530612  float64
# avg_rating              101                   10.306122  float64
# processor_speed          42                    4.285714  float64
# processor_brand          20                    2.040816   object
# os                       14                    1.428571   object
# battery_capacity         11                    1.122449  float64
# num_cores                 6                    0.612245   object
# primary_camera_front      5                    0.510204  float64

# %%
print('mean', df['fast_charging'].mean())
print('median', df['fast_charging'].median())
print('skew', df['fast_charging'].skew())
print('missing_value' , df['fast_charging'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['fast_charging'],color='skyblue')
# Out:
# mean 46.1261378413524
# median 33.0
# skew 1.6455706001461585
# missing_value 211
# <Axes: xlabel='fast_charging', ylabel='Density'>

# %%
df['fast_charging']=df['fast_charging'].fillna(df['fast_charging'].median())

# %%
print('mean', df['fast_charging'].mean())
print('median', df['fast_charging'].median())
print('skew', df['fast_charging'].skew())
print('missing_value' , df['fast_charging'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['fast_charging'],color='skyblue')
# Out:
# mean 43.3
# median 33.0
# skew 2.0318079072815896
# missing_value 0
# <Axes: xlabel='fast_charging', ylabel='Density'>

# %%
print('mean', df['avg_rating'].mean())
print('median', df['avg_rating'].median())
print('skew', df['avg_rating'].skew())
print('missing_value' , df['avg_rating'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['avg_rating'],color='skyblue')
# Out:
# mean 7.825824800910125
# median 8.0
# skew -0.6989993034105522
# missing_value 101
# <Axes: xlabel='avg_rating', ylabel='Density'>

# %%
df['avg_rating']=df['avg_rating'].fillna(df['avg_rating'].median())

# %%
print('mean', df['avg_rating'].mean())
print('median', df['avg_rating'].median())
print('skew', df['avg_rating'].skew())
print('missing_value' , df['avg_rating'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['avg_rating'],color='skyblue')
# Out:
# mean 7.8437755102040825
# median 8.0
# skew -0.8068570386027629
# missing_value 0
# <Axes: xlabel='avg_rating', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'avg_rating', '5G_or_not',
#        'processor_brand', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'os', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'resolution_height', 'resolution_width'],
#       dtype='object')

# %%
print('mean', df['primary_camera_front'].mean())
print('median', df['primary_camera_front'].median())
print('skew', df['primary_camera_front'].skew())
print('missing_value' , df['primary_camera_front'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['primary_camera_front'],color='skyblue')
# Out:
# mean 16.58974358974359
# median 16.0
# skew 1.4392943980315223
# missing_value 5
# <Axes: xlabel='primary_camera_front', ylabel='Density'>

# %%
df['primary_camera_front']=df['primary_camera_front'].fillna(df['primary_camera_front'].median())

# %%
print('mean', df['primary_camera_front'].mean())
print('median', df['primary_camera_front'].median())
print('skew', df['primary_camera_front'].skew())
print('missing_value' , df['primary_camera_front'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['primary_camera_front'],color='skyblue')
# Out:
# mean 16.586734693877553
# median 16.0
# skew 1.4437692193558938
# missing_value 0
# <Axes: xlabel='primary_camera_front', ylabel='Density'>

# %%
print('mean', df['processor_speed'].mean())
print('median', df['processor_speed'].median())
print('skew', df['processor_speed'].skew())
print('missing_value' , df['processor_speed'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['processor_speed'],color='skyblue')
# Out:
# mean 2.427217484008529
# median 2.3
# skew 0.18833557463624603
# missing_value 42
# <Axes: xlabel='processor_speed', ylabel='Density'>

# %%
df['processor_speed']=df['processor_speed'].fillna(df['processor_speed'].median())

# %%
print('mean', df['processor_speed'].mean())
print('median', df['processor_speed'].median())
print('skew', df['processor_speed'].skew())
print('missing_value' , df['processor_speed'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['processor_speed'],color='skyblue')
# Out:
# mean 2.421765306122449
# median 2.3
# skew 0.22666731817565902
# missing_value 0
# <Axes: xlabel='processor_speed', ylabel='Density'>

# %%
print('mean', df['battery_capacity'].mean())
print('median', df['battery_capacity'].median())
print('skew', df['battery_capacity'].skew())
print('missing_value' , df['battery_capacity'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['battery_capacity'],color = 'skyblue')
# Out:
# mean 4817.748194014448
# median 5000.0
# skew 9.260986328291185
# missing_value 11
# <Axes: xlabel='battery_capacity', ylabel='Density'>

# %%
df['battery_capacity']=df['battery_capacity'].fillna(df['battery_capacity'].median())

# %%
print('mean', df['battery_capacity'].mean())
print('median', df['battery_capacity'].median())
print('skew', df['battery_capacity'].skew())
print('missing_value' , df['battery_capacity'].isnull().sum())
plt.figure(figsize=(15,8))
sns.distplot(df['battery_capacity'], color= 'skyblue')
# Out:
# mean 4819.79387755102
# median 5000.0
# skew 9.302069825886411
# missing_value 0
# <Axes: xlabel='battery_capacity', ylabel='Density'>

# %%
total1=df.isnull().sum().sort_values(ascending=False)
percent1=(df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)
missing_data1=pd.concat([total1,percent1],axis=1, keys=['Total','Percentage of missing data'])
missing_data1['Type']=df[missing_data1.index].dtypes
missing_data1
# Out:
#                            Total  Percentage of missing data     Type
# brand_name                     0                         0.0   object
# model                          0                         0.0   object
# resolution_height              0                         0.0    int64
# extended_memory_available      0                         0.0   object
# primary_camera_front           0                         0.0  float64
# primary_camera_rear            0                         0.0  float64
# os                             0                         0.0   object
# num_rear_cameras               0                         0.0   object
# refresh_rate                   0                         0.0    int64
# screen_size                    0                         0.0  float64
# internal_memory                0                         0.0   object
# ram_capacity                   0                         0.0    int64
# ...

# %%
plt.figure(figsize=[15,8])
df.isnull().sum().plot(kind='bar')
plt.show()

# %%
#there is no missing value

# %%
df.describe().T
# Out:
#                       count          mean           std      min       25%  \
# price                 980.0  32520.504082  39531.812669  3499.00  12999.00
# avg_rating            980.0      7.843776      0.703059     6.00      7.50
# num_cores             980.0      7.773469      0.834466     4.00      8.00
# processor_speed       980.0      2.421765      0.454757     1.20      2.05
# battery_capacity      980.0   4819.793878   1004.036245  1821.00   4500.00
# fast_charging         980.0     43.300000     30.836247    10.00     25.00
# ram_capacity          980.0      6.560204      2.744378     1.00      4.00
# screen_size           980.0      6.536765      0.349162     3.54      6.50
# refresh_rate          980.0     92.256122     28.988052    60.00     60.00
# primary_camera_rear   980.0     50.319286     33.000968     2.00     24.00
# primary_camera_front  980.0     16.586735     10.849214     0.00      8.00
# ...

# %% [markdown]
# # checking the correlation and covariance between the variables

# %%
corr=df_num.corr()
corr.T
# Out:
#                          price  avg_rating  processor_speed  battery_capacity  \
# price                 1.000000    0.651771         0.674578         -0.259908
# avg_rating            0.651771    1.000000         0.550289         -0.182370
# processor_speed       0.674578    0.550289         1.000000         -0.120300
# battery_capacity     -0.259908   -0.182370        -0.120300          1.000000
# fast_charging         0.515371    0.463404         0.606112         -0.118087
# ram_capacity          0.618458    0.759316         0.473926         -0.224807
# screen_size           0.209992    0.179662         0.308080          0.223394
# refresh_rate          0.387146    0.406609         0.474506          0.119063
# primary_camera_rear   0.170808    0.450686         0.092499         -0.003282
# primary_camera_front  0.210845    0.487196         0.291405         -0.206937
# resolution_height    -0.041860    0.060102         0.095148          0.231108
# ...

# %%
#there is  positive correlation between avg_rating and ram_capacity of 0.76,processor_speed and price of 0.67
#there is no presence of negative correlartion

# %%
filter_corr = corr[(corr > 0.6) & (corr < 1)]
filter_corr
# Out:
#                          price  avg_rating  processor_speed  battery_capacity  \
# price                      NaN    0.651771         0.674578               NaN
# avg_rating            0.651771         NaN              NaN               NaN
# processor_speed       0.674578         NaN              NaN               NaN
# battery_capacity           NaN         NaN              NaN               NaN
# fast_charging              NaN         NaN         0.606112               NaN
# ram_capacity          0.618458    0.759316              NaN               NaN
# screen_size                NaN         NaN              NaN               NaN
# refresh_rate               NaN         NaN              NaN               NaN
# primary_camera_rear        NaN         NaN              NaN               NaN
# primary_camera_front       NaN         NaN              NaN               NaN
# resolution_height          NaN         NaN              NaN               NaN
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
cov=df_num.cov()
cov
# Out:
#                              price   avg_rating  processor_speed  \
# price                 9.021005e+07  2404.157055      2202.537544
# avg_rating            2.404157e+03     0.150827         0.074247
# processor_speed       2.202538e+03     0.074247         0.121307
# battery_capacity     -6.594467e+05   -18.920233       -11.218357
# fast_charging         1.230529e+05     4.558919         5.359005
# ram_capacity          1.078344e+04     0.541355         0.303956
# screen_size           2.240153e+02     0.007837         0.012072
# refresh_rate          9.235709e+04     3.966296         4.164435
# primary_camera_rear   3.197034e+04     3.449256         0.637788
# primary_camera_front  6.904454e+03     0.652352         0.350813
# resolution_height    -9.905635e+03     0.581551         0.830160
# resolution_width      0.000000e+00     0.000000         0.000000
#
#                       battery_capacity  fast_charging  ram_capacity  \
# ...

# %% [markdown]
# # Check the brand distribution

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'avg_rating', '5G_or_not',
#        'processor_brand', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'os', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'resolution_height', 'resolution_width'],
#       dtype='object')

# %%
df.groupby('brand_name')['model'].count().sort_values(ascending= False).head(10)
# Out:
# brand_name
# xiaomi      134
# samsung     132
# vivo        111
# realme       97
# oppo         88
# motorola     52
# apple        46
# oneplus      42
# poco         41
# tecno        33
# Name: model, dtype: int64

# %%
#xiaomi is the top brand

# %%
plt.figure(figsize=(10, 6))
df.groupby('brand_name')['model'].count().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Distribution of Smartphone Brands')
plt.xlabel('Brand')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %%
top_5_brand=df['brand_name'].value_counts().sort_values(ascending= False).head(5)
top_5_brand
# Out:
# brand_name
# xiaomi     134
# samsung    132
# vivo       111
# realme      97
# oppo        88
# Name: count, dtype: int64

# %%
#xiaomi,samsung,vivo,realme and oppo are the top 5 brands in the market

# %%
plt.figure(figsize=(10, 6))
top_5_brand.plot(kind='bar',color='skyblue')
plt.title('Distribution of 5 top brand Smartphone Brands')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Display size analysis

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'avg_rating', '5G_or_not',
#        'processor_brand', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'os', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'resolution_height', 'resolution_width'],
#       dtype='object')

# %% [markdown]
# # Create a histogram to visualise the distribution of display sizes.

# %%
df['screen_size'].value_counts().head(10)
# Out:
# screen_size
# 6.50    119
# 6.67     97
# 6.70     93
# 6.60     91
# 6.43     43
# 6.40     43
# 6.58     40
# 6.80     35
# 6.78     33
# 6.10     31
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,8))
df['screen_size'].hist(color='skyblue')
plt.title('Distribution of screen-size')
plt.xlabel('Frequency')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %%
# screen-size of the maximum phone are in the range of 6 to 7

# %% [markdown]
# # Calculate the average display size for each brand and plot a bar chart.

# %%
df.groupby('brand_name')['screen_size'].mean().sort_values(ascending=False)
# Out:
# brand_name
# royole       7.500000
# zte          6.850000
# lg           6.800000
# blu          6.800000
# nubia        6.756667
# huawei       6.745000
# tesla        6.730000
# infinix      6.718966
# lenovo       6.710000
# tecno        6.705455
# redmi        6.683333
# honor        6.657692
# asus         6.657143
# iqoo         6.623750
# poco         6.609756
# xiaomi       6.608955
# ikall        6.606667
# leitz        6.600000
# oneplus      6.589286
# motorola     6.577692
# oppo         6.575341
# nothing      6.574000
# lava         6.570000
# samsung      6.551212
# vivo         6.545946
# realme       6.524845
# micromax     6.520000
# letv         6.513333
# nokia        6.510769
# leeco        6.500000
# sharp        6.500000
# oukitel      6.473333
# doogee       6.440000
# gionee       6.420000
# cola         6.400000
# google       6.316429
# sony         6.266667
# blackview    6.100000
# apple        6.079565
# tcl          6.000000
# itel         5.989000
# ...

# %%
plt.figure(figsize=(10, 6))
df.groupby('brand_name')['screen_size'].mean().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Distribution of Screen size')
plt.xlabel('Brand')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %%
#royole is having the highest average screen-size of phone
#duoqin is having the smallest average screen-size of phone
#screen-size of  apple- 6.079565
# screen- size  of samsung - 6.551212
# screen-size of royole- 7.500000
#screen- size of duoqin - 3.540000

# %% [markdown]
# # Calculate the maximum display size for top 5 brand and what is its OS and plot a bar chart.

# %%
top_5_max_screen_brand=df.groupby(['brand_name','os'])['screen_size'].max().sort_values(ascending=False).head(5)
top_5_max_screen_brand
# Out:
# brand_name  os
# vivo        android    8.03
# xiaomi      android    8.02
# huawei      android    8.00
# royole      android    7.80
# samsung     android    7.60
# Name: screen_size, dtype: float64

# %%
top_5_max_screen_brand_df = top_5_max_screen_brand.reset_index()
top_5_max_screen_brand_df
# Out:
#   brand_name       os  screen_size
# 0       vivo  android         8.03
# 1     xiaomi  android         8.02
# 2     huawei  android         8.00
# 3     royole  android         7.80
# 4    samsung  android         7.60

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_max_screen_brand_df, x='screen_size', y='brand_name', hue='os', dodge=False)
plt.title('Maximum Screen Size for Top 5 Brands with Corresponding OS')
plt.xlabel('Screen Size')
plt.ylabel('Brand Name')
plt.show()

# %%
#vivo and xiaomi are having maximum screen size and they both are having android os
# samsung is having 5th maximum screen size of 7.60

# %% [markdown]
# # Calculate the minimum display size for top 5 brand and what is its OS and plot a bar chart.

# %%
top_5_min_screen_brand=df.groupby(['brand_name','os'])['screen_size'].min().sort_values(ascending=True).head(5)
top_5_min_screen_brand
# Out:
# brand_name  os
# duoqin      android    3.54
# cat         android    4.00
# vivo        android    4.50
# apple       ios        4.70
# vertu       android    4.70
# Name: screen_size, dtype: float64

# %%
top_5_min_screen_brand_df = top_5_min_screen_brand.reset_index()
top_5_min_screen_brand_df
# Out:
#   brand_name       os  screen_size
# 0     duoqin  android         3.54
# 1        cat  android         4.00
# 2       vivo  android         4.50
# 3      apple      ios         4.70
# 4      vertu  android         4.70

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=top_5_min_screen_brand_df, x='screen_size', y='brand_name', hue='os', dodge=False)
plt.title('Minimum Screen Size for Top 5 Brands with Corresponding OS')
plt.xlabel('Screen Size')
plt.ylabel('Brand Name')
plt.show()

# %%
#duoqin is having smallest screen size of 3.54 and its os is android
#apple phones are the 4th smallest sceen size phone of 4.70 and its os is ios

# %%
df_cat.columns
# Out:
# Index(['brand_name', 'model', '5G_or_not', 'processor_brand', 'num_cores',
#        'fast_charging_available', 'internal_memory', 'num_rear_cameras', 'os',
#        'extended_memory_available'],
#       dtype='object')

# %% [markdown]
# # Check the average price distribution in different OS and plot barplot of it.

# %%
df.groupby('os')['price'].mean().sort_values(ascending=False)
# Out:
# os
# ios        95966.521739
# other      65646.181818
# android    28963.733478
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='price',x='os',data=df)
plt.title('Average phone price in different os')
plt.ylabel('Price')
plt.xlabel('os')
plt.show()

# %%
#the average price of ios phone is 95966 and its cost high then others operating system phone

# %% [markdown]
# # Check the maximum top 10 price distribution in different OS and plot barplot of it.

# %%
#the maximum price of the phone is 650000 and its operating system is of android

# %%
max_price_indices = df.groupby('brand_name')['price'].idxmax()
max_prices_with_os = df.loc[max_price_indices, ['brand_name', 'price', 'os']]
max_prices_with_os_sorted = max_prices_with_os.sort_values(by='price', ascending=False)
max_10_price_brand_os=(max_prices_with_os_sorted.head(10))
max_10_price_brand_os
# Out:
#     brand_name   price       os
# 732      vertu  650000  android
# 909     xiaomi  480000  android
# 94      huawei  239999    other
# 32       apple  182999      ios
# 686    samsung  163980  android
# 554     royole  149999  android
# 696       sony  134999  android
# 408       oppo  134999  android
# 189      leitz  124990  android
# 781       vivo  119990  android

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=max_10_price_brand_os, x='price', y='brand_name', hue='os', dodge=False)
plt.title('Maximum Price for Each Brand with Corresponding OS')
plt.xlabel('Price')
plt.ylabel('Brand Name')
plt.show()

# %%
#650000 is the maximum cost of phones
#vertu cost the most expensive brand of phones which is having android operating system

# %%
df.groupby('os')['price'].min()
# Out:
# os
# android     3499
# ios        29990
# other       6190
# Name: price, dtype: int64

# %%
#the minimum price of the phone is 3499 and its operating system is of android

# %%
min_price_indices = df.groupby('brand_name')['price'].idxmin()
min_prices_with_os = df.loc[min_price_indices, ['brand_name', 'price', 'os']]
min_prices_with_os_sorted = min_prices_with_os.sort_values(by='price', ascending=True)
min_10_price_brand_os=(min_prices_with_os_sorted.head(10))
min_10_price_brand_os
# Out:
#     brand_name  price       os
# 497     realme   3499  android
# 199        lyf   3890  android
# 170       itel   3999  android
# 183        jio   4499  android
# 555    samsung   4999  android
# 255      nokia   5249  android
# 192       letv   5499  android
# 202   micromax   5999  android
# 906     xiaomi   6171  android
# 60      gionee   6190    other

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=min_10_price_brand_os, x='price', y='brand_name', hue='os', dodge=False)
plt.title('Maximum Price for Each Brand with Corresponding OS')
plt.xlabel('Price')
plt.ylabel('Brand Name')
plt.show()

# %%
#3499 is the minimum price of  phones
#realme cost the lowest among all the other brand phones which is having android operating system

# %% [markdown]
# # Check whether maximum avg-rating,processor-speed and ram-capacity is related with top 10 maximum price of phone brand and their os.

# %%
df.groupby(['os','brand_name','processor_speed','avg_rating','ram_capacity'])['price'].max().sort_values(ascending=False).head(10)
# Out:
# os       brand_name  processor_speed  avg_rating  ram_capacity
# android  vertu       1.50             6.2         2               650000
#          xiaomi      2.80             8.8         8               480000
# other    huawei      3.20             8.1         12              239999
# android  huawei      2.86             8.0         12              214990
#          xiaomi      2.96             8.0         12              199990
# ios      apple       2.30             7.8         6               182999
#                      3.22             8.6         6               179900
#                      2.30             7.7         6               172999
# android  huawei      2.86             8.0         8               169000
#          samsung     3.20             8.0         12              163980
# Name: price, dtype: int64

# %%
df.groupby(['os','brand_name','price','avg_rating','ram_capacity'])['processor_speed'].max().sort_values(ascending=False).head(10)
# Out:
# os   brand_name  price   avg_rating  ram_capacity
# ios  apple       75999   8.2         6               3.22
#                  129900  8.3         6               3.22
#                  64900   7.9         4               3.22
#                  65999   8.1         6               3.22
#                  49990   6.0         4               3.22
#                  72999   7.9         4               3.22
#                  74999   8.2         6               3.22
#                  84999   8.3         6               3.22
#                  91999   8.0         4               3.22
#                  95999   8.2         6               3.22
# Name: processor_speed, dtype: float64

# %% [markdown]
# Distribution of maximum processor-speed of different phone-brands.

# %%
plt.figure(figsize=(10, 6))
df.groupby('brand_name')['processor_speed'].max().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Distribution of Smartphone Brands')
plt.xlabel('Brand')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %%
# from this we can conclude that the phone which is in maximum price is having poor processor speed.
#while the maximum top 10 good processor speed are of ios phones

# %%
df.groupby(['os','brand_name','avg_rating','processor_speed','price'])['ram_capacity'].max().sort_values(ascending=False).head(10)
# Out:
# os       brand_name  avg_rating  processor_speed  price
# android  asus        8.7         3.20             75990     18
#                      8.8         3.20             89999     18
#                      8.0         3.20             107990    16
#          oneplus     8.7         3.20             55999     16
#          oppo        8.6         2.85             39999     16
#                                  3.20             45999     16
#          lenovo      8.9         2.84             59999     16
#          tesla       8.3         2.30             69999     16
#          iqoo        8.9         3.20             64999     16
#          oppo        8.6         3.05             42990     16
# Name: ram_capacity, dtype: int64

# %% [markdown]
# Distribution of maximum ram-capacity of different phone-brands.

# %%
plt.figure(figsize=(10, 6))
df.groupby('brand_name')['ram_capacity'].max().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Distribution of Smartphone Brands')
plt.xlabel('Brand')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()

# %%
#here we observe that the maximum rating of top 10 phones are having reasonable price and good proessing speed and avg_rating

# %%
df.groupby(['os','brand_name','ram_capacity','processor_speed','price'])['avg_rating'].max().sort_values(ascending=False).head(10)
# Out:
# os       brand_name  ram_capacity  processor_speed  price
# android  realme      8             3.00             49959     8.9
#          sony        8             2.84             69999     8.9
#          samsung     12            2.84             110999    8.9
#                                    2.73             58999     8.9
#                                    2.70             92999     8.9
#                      8             3.20             84990     8.9
#                                    2.73             74999     8.9
#          huawei      8             2.84             162990    8.9
#          samsung     8             2.40             36499     8.9
#                                                     33499     8.9
# Name: avg_rating, dtype: float64

# %%
#realme is one of the best rating with low price and good ram-capacity along with good processing- speed

# %% [markdown]
# Distribution of maximum avg-rating of different phone-brands.

# %%
plt.figure(figsize=(10, 6))
df.groupby('brand_name')['avg_rating'].max().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Distribution of Smartphone Brands')
plt.xlabel('Brand')
plt.xticks(rotation=90, ha='right')  
plt.tight_layout()
plt.show()
